# %%
BASE_PATH = "/content/drive/MyDrive/Académico/UNIR/MUQC/99 - TFM/dev"

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import random
import time
import pandas as pd
# usaremos "from pennylane import numpy as np" tras la instalación de PennyLane para el uso de los métodos de diferenciación automática
#import numpy as np
import matplotlib.pyplot as plt
#import tensorflow as tf

# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading PennyLane-0.36.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane) (3.3)
# Collecting rustworkx (from pennylane)
#   Downloading rustworkx-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 46.8 MB/s eta 0:00:00
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane) (0.10.2)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting semantic-version>=2.7 (from pennylane)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting autoray>=0.6.1 (from pennylane)
#   Downloading autoray-0.6.12-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane) (5.3.3)
# Collecting pennylane-lightning>=0.36 (from pennylane)
#   Downloading PennyLane_Lightning-0.36.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 78.2 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane) (4.12.2)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane) (2024.6.2)
# Installing collected packages: appdirs, semantic-version, rustworkx, autoray, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.6.12 pennylane-0.36.0 pennylane-lightning-0.36.0 rustworkx-0.14.2 semantic-version-2.10.0

# %%
# !pip install cuquantum
# Out:
# Collecting cuquantum
#   Downloading cuquantum-24.3.0.post1.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cuquantum-cu12==24.03.0.post1 (from cuquantum)
#   Downloading cuquantum_cu12-24.3.0.post1-py3-none-manylinux2014_x86_64.whl (7.5 kB)
# Collecting custatevec-cu12==1.6.0.post1 (from cuquantum-cu12==24.03.0.post1->cuquantum)
#   Downloading custatevec_cu12-1.6.0.post1-py3-none-manylinux2014_x86_64.whl (38.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.7/38.7 MB 42.8 MB/s eta 0:00:00
# Collecting cutensornet-cu12==2.4.0.post1 (from cuquantum-cu12==24.03.0.post1->cuquantum)
#   Downloading cutensornet_cu12-2.4.0.post1-py3-none-manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 89.8 MB/s eta 0:00:00
# Collecting cutensor-cu12<3,>=2.0.1 (from cutensornet-cu12==2.4.0.post1->cuquantum-cu12==24.03.0.post1->cuquantum)
#   Downloading cutensor_cu12-2.0.1-py3-none-manylinux2014_x86_64.whl (152.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 MB 4.4 MB/s eta 0:00:00
# Building wheels for collected packages: cuquantum
#   Building wheel for cuquantum (setup.py) ... done
#   Created wheel for cuquantum: filename=cuquantum-24.3.0.post1-0_cu12-py3-none-any.whl size=10532 sha256=17416522a027418e389d53be0632559c2b9a72b2810979650f8f0af3bfeb3723
#   Stored in directory: /root/.cache/pip/wheels/1d/4e/b7/1ae412184f72b750bf9429ca492cf9d4aeb405e7846a9e0907
# Successfully built cuquantum
# Installing collected packages: cutensor-cu12, custatevec-cu12, cutensornet-cu12, cuquantum-cu12, cuquantum
# Successfully installed cuquantum-24.3.0.post1 cuquantum-cu12-24.3.0.post1 custatevec-cu12-1.6.0.post1 cutensor-cu12-2.0.1 cutensornet-cu12-2.4.0.post1

# %%
# !pip install pennylane-lightning[gpu]
# Out:
# Requirement already satisfied: pennylane-lightning[gpu] in /usr/local/lib/python3.10/dist-packages (0.36.0)
# Requirement already satisfied: pennylane>=0.34 in /usr/local/lib/python3.10/dist-packages (from pennylane-lightning[gpu]) (0.36.0)
# Collecting pennylane-lightning-gpu (from pennylane-lightning[gpu])
#   Downloading PennyLane_Lightning_GPU-0.36.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 58.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (1.11.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (3.3)
# Requirement already satisfied: rustworkx in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (0.14.2)
# Requirement already satisfied: autograd in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (1.6.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (1.4.4)
# Requirement already satisfied: semantic-version>=2.7 in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (2.10.0)
# Requirement already satisfied: autoray>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (0.6.12)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (5.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from pennylane>=0.34->pennylane-lightning[gpu]) (4.12.2)
# Requirement already satisfied: future>=0.15.2 in /usr/local/lib/python3.10/dist-packages (from autograd->pennylane>=0.34->pennylane-lightning[gpu]) (0.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane>=0.34->pennylane-lightning[gpu]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane>=0.34->pennylane-lightning[gpu]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane>=0.34->pennylane-lightning[gpu]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->pennylane>=0.34->pennylane-lightning[gpu]) (2024.6.2)
# Installing collected packages: pennylane-lightning-gpu
# Successfully installed pennylane-lightning-gpu-0.36.0

# %%
from pennylane import numpy as np

# %%
N_QUBITS = 8

# %%
RANDOM_SEED = 1234

random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
#tf.random.set_seed(RANDOM_SEED)

# %%
PCA_COMPONENTS = 8

# %%
df_tr_day_syn_resampled = pd.read_csv(BASE_PATH + "/dataset/tr_day_syn_small.csv")

# %%
df_test_day_syn_resampled = pd.read_csv(BASE_PATH + "/dataset/test_day_syn_small.csv")

# %%
x_tr = df_tr_day_syn_resampled.drop(columns = " Label").to_numpy()

# %%
y_tr = df_tr_day_syn_resampled[" Label"].to_numpy()

# %%
x_test = df_test_day_syn_resampled.drop(columns = " Label").to_numpy()

# %%
y_test = df_test_day_syn_resampled[" Label"].to_numpy()

# %%
from sklearn.model_selection import train_test_split

# %%
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, train_size = 0.5, stratify = y_test)

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler = MaxAbsScaler()
x_tr = scaler.fit_transform(x_tr)

x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

# %%
x_test = np.clip(x_test, 0, 1)
x_val = np.clip(x_val, 0, 1)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = PCA_COMPONENTS)

# %%
start = time.time()

xs_tr = pca.fit_transform(x_tr)
xs_test = pca.transform(x_test)
xs_val = pca.transform(x_val)

end = time.time()
print(f"Elapsed time: {end - start} s")
# Out:
# Elapsed time: 0.4048423767089844 s

# %%
import pennylane as qml

# %%
dev = qml.device("lightning.gpu", wires = N_QUBITS)

# %%
from itertools import combinations

def ZZFeatureMap(nqubits, data):
  nload = min(len(data), nqubits)

  for i in range(nload):
    qml.Hadamard(i)
    qml.RZ(2.0 * data[i], wires = i)

  for pair in list(combinations(range(nload), 2)):
    q0 = pair[0]
    q1 = pair[1]

    qml.CZ(wires = [q0, q1])
    qml.RZ(2.0 * (np.pi - data[q0]) * (np.pi - data[q1]), wires = q1)
    qml.CZ(wires = [q0, q1])

@qml.qnode(dev)
def kernel_circ(a, b):
  ZZFeatureMap(N_QUBITS, a)
  qml.adjoint(ZZFeatureMap)(N_QUBITS, b)
  return qml.probs(wires = range(N_QUBITS))

# %%
print(qml.draw_mpl(kernel_circ)(xs_tr[0], xs_tr[0]))
# Out:
# (<Figure size 17500x900 with 1 Axes>, <Axes: >)

# %%
def qkernel(A, B):
  return np.array([[kernel_circ(a, b)[0] for b in B] for a in A])

# %%
from sklearn import svm

model = svm.SVC(kernel = qkernel)

# %%
start = time.time()

# %%
model.fit(xs_tr, y_tr)
# Out:
# SVC(kernel=<function qkernel at 0x7c6bedb7dcf0>)

# %%
end = time.time()
print(f"Elapsed time: {end - start} s")
# Out:
# Elapsed time: 18115.92204093933 s

# %%
from sklearn.metrics import accuracy_score

start = time.time()

tr_acc = accuracy_score(model.predict(xs_tr) >= 0.5, y_tr)
val_acc = accuracy_score(model.predict(xs_val) >= 0.5, y_val)
test_acc = accuracy_score(model.predict(xs_test) >= 0.5, y_test)

end = time.time()
print(f"Elapsed time: {end - start} s")
# Out:
# Elapsed time: 23312.324117422104 s

# %%
print("Train accuracy:", tr_acc)
print("Validation accuracy:", val_acc)
print("Test accuracy:", test_acc)
# Out:
# Train accuracy: 0.9975
# Validation accuracy: 0.94
# Test accuracy: 0.97

# %%
from sklearn.metrics import confusion_matrix

# %%
output = model.predict(xs_test)
result = (output > 0.5).astype(float)

# %%
confusion_matrix(y_true = y_test, y_pred = result)
# Out:
# array([[90,  0],
#        [ 3,  7]])

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true = y_test, y_pred = result))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98        90
#            1       1.00      0.70      0.82        10
#
#     accuracy                           0.97       100
#    macro avg       0.98      0.85      0.90       100
# weighted avg       0.97      0.97      0.97       100

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr, _ = roc_curve(y_test, output)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle = "--", color = "black")
plt.xlabel("FPR"); plt.ylabel("TPR")
plt.show()

# %%
from sklearn.metrics import auc

print(auc(fpr, tpr))
# Out:
# 0.85
